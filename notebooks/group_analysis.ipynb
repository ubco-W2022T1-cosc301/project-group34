# %% [markdown]
# ## Task 4: Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %% [markdown]
# #### Nick's portion

# %%
import project_functions_nick as pn 
data = pn.load_and_process("../data/processed/combined_nick.csv")
data
# Out:
#             Entity  Year  Aquaculture production (metric tons)  \
# 0      Afghanistan  1969                                  60.0
# 1      Afghanistan  1970                                  60.0
# 2      Afghanistan  1971                                  60.0
# 3      Afghanistan  1972                                  60.0
# 4      Afghanistan  1973                                  60.0
# ...            ...   ...                                   ...
# 16719        World  1955                                   NaN
# 16720        World  1956                                   NaN
# 16721        World  1957                                   NaN
# 16722        World  1958                                   NaN
# 16723        World  1959                                   NaN
#
#        Capture fisheries production (metric tons)  Sea food supply  \
# 0                                           400.0             0.04
# 1                                           400.0             0.04
# ...

# %% [markdown]
# My primary interest targets on how aquaculture production(i.e the sustainable fish stock in general) has whether helped alleviate the shortage of global fish stock cause by overfishing. Here we will take our focus on the two primary columns for the analysis, _Sustainable fish stock share_ and _Overexploited fish stock share_. It is important to keep in mind that the two columns focus on sea regions rather than countries, so the data will not be as rich when compared to countries.

# %%
data_preview = data.copy().describe().T
data_preview
# Out:
#                                               count          mean  \
# Year                                        16724.0  1.989359e+03
# Aquaculture production (metric tons)        11657.0  1.702216e+06
# Capture fisheries production (metric tons)  14516.0  2.842715e+06
# Sea food supply                             11028.0  1.667087e+01
# Sustainable fish stock share                   51.0  7.052158e+01
# Overexploited fish stock share                 51.0  2.947842e+01
# Artisanal fisheries                            61.0  1.518018e+07
# Discards portion                               61.0  1.183483e+07
# Industrial fisheries                           61.0  5.949119e+07
# Pelagic Fish production                      8740.0  8.776851e+05
# Crustaceans production                       9180.0  1.280381e+05
# Cephalopods production                       7490.0  6.780081e+04
# Demersal Fish production                     8504.0  4.989167e+05
# ...

# %% [markdown]
# Here we can tell that the mean Sustainable fish stock share has surpasses the Overexploited fish stock share and takes greater portion in gthe overall fishery production. The main fishery method is predominantly industrial, and Artisanal fisheries only takes 1/5 portion when compared to industrial fishing, which isn't surprising as many countries have developed advanced fishing machinery and equipments. The problem is whether such industrialized method has helped to reduced the amount of overfishing?

# %%
import matplotlib.pyplot as plt

df = data.copy().describe()
df = df.filter(items=['Aquaculture production (metric tons)', 'Capture fisheries production (metric tons)'])

fig, ax = plt.subplots(figsize=(20, 7))
dfg= sns.barplot(data=df, ax=ax)
for item in dfg.get_xticklabels():
    item.set_rotation(45)

# %% [markdown]
# A bar chart of the mean production by aquaculture and capture method. Here we can see that the aquaculture production has a slightly higher portion than the one in capture fisheries production, roughtly about 15% higher, which may indicate that Aquaculture is still the main preference for these region to produce fish. Bare in mind that the Aquaculture is part of the sustainable method that reduces the impact of climate change. However, the capture fisheries still remains large, I assumed that this change of production only happens recently by the awareness of the climate change, or perhaps it may caused by many fishery production has not made a proper transition to aquaculture, or even many fish stock avaliable is not viable for aquaculture.

# %% [markdown]
# #### Lily's portion

# %%
import project_functions_lily as pl
cleaned_df1 = pl.load_and_process_df1('../data/raw/global-fishery-catch-by-sector.csv')
cleaned_df1
# Out:
#     Unnamed: 0 Entity  Year  Artisanal (small-scale commercial)  Discards  \
# 0            0  World  1950                             7526795   5874170
# 1            1  World  1951                             8278304   6278225
# 2            2  World  1952                             8272109   7230311
# 3            3  World  1953                             8469284   7172937
# 4            4  World  1954                             9226926   8012930
# ..         ...    ...   ...                                 ...       ...
# 56          56  World  2006                            21417851   9530758
# 57          57  World  2007                            21097388   9725492
# 58          58  World  2008                            21111836   9568906
# 59          59  World  2009                            21828623   9369530
# 60          60  World  2010                            21586606   9638888
#
#     Industrial (large-scale commercial)  Recreational  Subsistence
# ...

# %%
cleaned_df2 = pl.load_and_process_df1('../data/raw/global-fishery-catch-by-sector.csv')
cleaned_df2
# Out:
#     Unnamed: 0                       Entity  Year  \
# 0            0     Eastern Central Atlantic  2015
# 1            1     Eastern Central Atlantic  2017
# 2            2      Eastern Central Pacific  2015
# 3            3      Eastern Central Pacific  2017
# 4            4         Eastern Indian Ocean  2015
# 5            5         Eastern Indian Ocean  2017
# 6            6  Mediterranean and Black Sea  2015
# 7            7  Mediterranean and Black Sea  2017
# 8            8   Northeast Central Atlantic  2015
# 9            9   Northeast Central Atlantic  2017
# 10          10            Northeast Pacific  2015
# 11          11            Northeast Pacific  2017
# 12          12   Northwest Central Atlantic  2015
# 13          13   Northwest Central Atlantic  2017
# 14          14            Northwest Pacific  2015
# 15          15            Northwest Pacific  2017
# 16          16   Southeast Central Atlantic  2015
# 17          17   Southeast Central Atlantic  2017
# ...

# %% [markdown]
# My primary interest focuses around how the results of overfishing impact our wild fish stock over the next decade. Here we can see in the two different tables, first that over the past 10 years it varies depending on the location the overexploitation and the sustainable fish stock percentages. However, if we focus in on it being the world in general we can see the shift towards the share of fish that is being overexploited. Over the last 10 or so years the share of fish being overexploited grew around 2%. It is likely that if we are continuning at a similar projectory that in the next 10 years it will grow by another 2%. This is likely due to the ever growing demand for fish and the growing numbers in fish caught. When you look at first table it shows that the amount of fishing in all categories have dramatically grown from over the last 10 and 50 years. It is likely that it will continue growing from the current trend.In certain sectors of fishing(large scale) it has grown hundreds of thousands to millions. If we continue at this rate it is very likely that the amount of fish that are being overexploited will continue to grow.

# %% [markdown]
# #### Livia's portion

# %%
import project_functions_livia as pl

# Export merged table
combined_df.to_csv('../data/processed/combined_livia.csv', index=False)

# %%
cleaned_dataset = pl.load_and_process("../data/processed/combined_livia.csv")
cleaned_dataset

# The result:
# Out:
#        Unnamed: 0                       Entity  Year  \
# 0               0     Eastern Central Atlantic  2015
# 1               1      Eastern Central Pacific  2015
# 2               2         Eastern Indian Ocean  2015
# 3               3  Mediterranean and Black Sea  2015
# 4               4   Northeast Central Atlantic  2015
# ...           ...                          ...   ...
# 16719       16719                          NaN  1955
# 16720       16720                          NaN  1956
# 16721       16721                          NaN  1957
# 16722       16722                          NaN  1958
# 16723       16723                          NaN  1959
#
#        Fish stocks within biologically sustainable levels  \
# 0                                               57.14286
# 1                                               86.66667
# 2                                               73.07692
# 3                                               37.83784
# ...

# %% [markdown]
# My primary interest targets on whether industrial fishing will be able to meet the demands of fish stock from the increasing global population or experience a shortage of global fish stock caused by overfishing. Based on the dataset, we will focus on three different variables, 'Fish stocks within biologically sustainable levels', 'Overexploited fish stocks', and 'Industrial (large-scale commercial)'. As we look at the trends for fish being overexploited, we can see a dramatic increase fom over the last 50 years. It is likely that we will experience a shortage of global fish stock caused by overfishing and we won't be able to meet the demands of the global population.

# %% [markdown]
# #### Conclusion

# %% [markdown]
# In exploring the global production of marine fisheries and its effects on climate change through overexploitation of fish stocks within the past 50 years, some questions we had investigated are:
# - How will commercial fishing be able to meet the demands of fish stock from the increasing global population?
# - How will the results of overfishing impact our wild fish stock over the next decade?
# - What contributions will aquaculture make in sustainable practices of fishing?
#
# As we look at the trends for fish being overexploited, we can see a dramatic increase fom over the last 50 years. It is likely that we will experience a shortage of global fish stock caused by overfishing and we won't be able to meet the demands of the global population. However, in the last 10 or so years the share of fish being overexploited grew around 2%. It is likely that if we are continuning at a similar projectory that in the next 10 years it will grow by another 2%. This is likely due to the ever growing demand for fish and the growing numbers in fish caught. If we continue at this rate it is very likely that the amount of fish that are being overexploited will continue to grow. Furthermore, the capture fisheries still remains large. We assumed that this change of sustainable production only happens recently by the awareness of the climate change, or perhaps it may caused by many fishery production has not made a proper transition to aquaculture, or even many fish stock avaliable is not viable for aquaculture.
